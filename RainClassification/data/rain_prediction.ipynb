# %%
import pandas as pd

# %%
data = pd.read_csv("new_data.csv", index_col=0)

# %%
data.head()
# Out:
#    1:Date  2:Time  3:Temperature_Comedor_Sensor  \
# 0      13     705                       18.1875
# 1      13     720                       18.4633
# 2      13     735                       18.7673
# 3      13     750                       19.0727
# 4      13     765                       19.3721
#
#    4:Temperature_Habitacion_Sensor  5:Weather_Temperature  \
# 0                          17.8275                    0.0
# 1                          18.1207                    6.8
# 2                          18.4367                   17.0
# 3                          18.7513                   18.0
# 4                          19.0414                   20.0
#
#    6:CO2_Comedor_Sensor  7:CO2_Habitacion_Sensor  8:Humedad_Comedor_Sensor  \
# 0               216.560                  221.920                   39.9125
# 1               219.947                  220.363                   39.9267
# 2               219.403                  218.933                   39.7720
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4137 entries, 0 to 4136
# Data columns (total 25 columns):
# 1:Date                             4137 non-null int64
# 2:Time                             4137 non-null int64
# 3:Temperature_Comedor_Sensor       4137 non-null float64
# 4:Temperature_Habitacion_Sensor    4137 non-null float64
# 5:Weather_Temperature              4137 non-null float64
# 6:CO2_Comedor_Sensor               4137 non-null float64
# 7:CO2_Habitacion_Sensor            4137 non-null float64
# 8:Humedad_Comedor_Sensor           4137 non-null float64
# 9:Humedad_Habitacion_Sensor        4137 non-null float64
# 10:Lighting_Comedor_Sensor         4137 non-null float64
# 11:Lighting_Habitacion_Sensor      4137 non-null float64
# 12:Precipitacion                   4137 non-null float64
# 13:Meteo_Exterior_Crepusculo       4137 non-null float64
# 14:Meteo_Exterior_Viento           4137 non-null float64
# 15:Meteo_Exterior_Sol_Oest         4137 non-null float64
# ...

# %%
count_zero = 0
count_one = 0
for i in range(0, 4137):
    if data.loc[i, '12:Precipitacion'] > 0:
        data.loc[i, '12:Precipitacion'] = 1
        count_one = count_one + 1
    else:
        count_zero = count_zero + 1
        
print("Zeros: ", count_zero)
print("Ones: ", count_one)
# Out:
# Zeros:  3953
# Ones:  184
