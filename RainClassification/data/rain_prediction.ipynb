# %%
import pandas as pd

# %%
data = pd.read_csv("base_Intervalo.csv")

# %%
data.head()
# Out:
#    id  rain period  SUM(weather_info.Temperature_Comedor_Sensor)  \
# 0   1     0  11:45                                       93.8629
# 1   2     0  13:00                                      100.7687
# 2   3     0  14:15                                      106.0292
# 3   4     0  15:30                                      108.0693
# 4   5     0  16:45                                      108.9093
#
#    SUM(weather_info.Temperature_Habitacion_Sensor)  \
# 0                                          92.1776
# 1                                          98.6547
# 2                                         104.9793
# 3                                         113.4293
# 4                                         119.1186
#
#    SUM(weather_info.Weather_Temperature)  SUM(weather_info.CO_Comedor_Sensor)  \
# 0                                61.8000                             1092.237
# 1                               100.0000                             1086.015
# 2                                98.6667                             1074.751
# 3                                90.8667                             1050.624
# 4                                92.4000                             1059.446
#
#    SUM(weather_info.CO_Habitacion_Sensor)  \
# 0                                1094.341
# 1                                1075.594
# 2                                1088.544
# 3                                1075.626
# 4                                1083.467
#
#    SUM(weather_info.Humedad_Comedor_Sensor)  \
# 0                                  199.1629
# 1                                  199.3947
# 2                                  204.3294
# 3                                  213.5226
# 4                                  206.1040
#
#    SUM(weather_info.Humedad_Habitacion_Sensor)  \
# 0                                     211.0543
# 1                                     210.1921
# 2                                     207.9908
# 3                                     201.6507
# 4                                     190.6320
#
#                 ...                MEAN(weather_info.Meteo_Exterior_Sol_Oest)  \
# 0               ...                                                 15906.588
# 1               ...                                                 59916.820
# 2               ...                                                 89120.220
# 3               ...                                                 85221.380
# 4               ...                                                 37208.668
#
#    MEAN(weather_info.Meteo_Exterior_Sol_Est)  \
# 0                                  10383.496
# 1                                   8763.598
# 2                                   9572.148
# 3                                   7599.514
# 4                                   4092.928
#
#    MEAN(weather_info.Meteo_Exterior_Sol_Sud)  \
# 0                                   95397.48
# 1                                   92990.14
# 2                                   67803.02
# 3                                   29457.62
# 4                                    6598.25
#
#    MEAN(weather_info.Meteo_Exterior_Piranometro)  \
# 0                                      763.19600
# 1                                      718.36160
# 2                                      579.05060
# 3                                      367.47100
# 4                                      107.55146
#
#    MEAN(weather_info.Exterior_Entalpic_)  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
#
#    MEAN(weather_info.Exterior_Entalpic_.1)  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
#
#    MEAN(weather_info.Exterior_Entalpic_turbo)  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    MEAN(weather_info.Temperature_Exterior_Sensor)  \
# 0                                        18.88274
# 1                                        20.86028
# 2                                        22.01306
# 3                                        21.44506
# 4                                        20.22202
#
#    MEAN(weather_info.Humedad_Exterior_Sensor)  MEAN(weather_info.Day_Of_Week)
# 0                                    47.22266                             2.0
# 1                                    45.22666                             2.0
# 2                                    44.49334                             2.0
# 3                                    45.31572                             2.0
# 4                                    44.78240                             2.0
#
# [5 rows x 87 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828 entries, 0 to 827
# Data columns (total 87 columns):
# id                                                  828 non-null int64
# rain                                                828 non-null int64
# period                                              828 non-null object
# SUM(weather_info.Temperature_Comedor_Sensor)        828 non-null float64
# SUM(weather_info.Temperature_Habitacion_Sensor)     828 non-null float64
# SUM(weather_info.Weather_Temperature)               828 non-null float64
# SUM(weather_info.CO_Comedor_Sensor)                 828 non-null float64
# SUM(weather_info.CO_Habitacion_Sensor)              828 non-null float64
# SUM(weather_info.Humedad_Comedor_Sensor)            828 non-null float64
# SUM(weather_info.Humedad_Habitacion_Sensor)         828 non-null float64
# SUM(weather_info.Lighting_Comedor_Sensor)           828 non-null float64
# SUM(weather_info.Lighting_Habitacion_Sensor)        828 non-null float64
# SUM(weather_info.Meteo_Exterior_Crepusculo)         828 non-null float64
# SUM(weather_info.Meteo_Exterior_Viento)             828 non-null float64
# SUM(weather_info.Meteo_Exterior_Sol_Oest)           828 non-null float64
# SUM(weather_info.Meteo_Exterior_Sol_Est)            828 non-null float64
# SUM(weather_info.Meteo_Exterior_Sol_Sud)            828 non-null float64
# SUM(weather_info.Meteo_Exterior_Piranometro)        828 non-null float64
# SUM(weather_info.Exterior_Entalpic_)                828 non-null int64
# SUM(weather_info.Exterior_Entalpic_.1)              828 non-null int64
# SUM(weather_info.Exterior_Entalpic_turbo)           828 non-null int64
# SUM(weather_info.Temperature_Exterior_Sensor)       828 non-null float64
# SUM(weather_info.Humedad_Exterior_Sensor)           828 non-null float64
# SUM(weather_info.Day_Of_Week)                       828 non-null float64
# MIN(weather_info.Temperature_Comedor_Sensor)        828 non-null float64
# MIN(weather_info.Temperature_Habitacion_Sensor)     828 non-null float64
# MIN(weather_info.Weather_Temperature)               828 non-null float64
# MIN(weather_info.CO_Comedor_Sensor)                 828 non-null float64
# MIN(weather_info.CO_Habitacion_Sensor)              828 non-null float64
# MIN(weather_info.Humedad_Comedor_Sensor)            828 non-null float64
# MIN(weather_info.Humedad_Habitacion_Sensor)         828 non-null float64
# MIN(weather_info.Lighting_Comedor_Sensor)           828 non-null float64
# MIN(weather_info.Lighting_Habitacion_Sensor)        828 non-null float64
# MIN(weather_info.Meteo_Exterior_Crepusculo)         828 non-null float64
# MIN(weather_info.Meteo_Exterior_Viento)             828 non-null float64
# MIN(weather_info.Meteo_Exterior_Sol_Oest)           828 non-null float64
# MIN(weather_info.Meteo_Exterior_Sol_Est)            828 non-null float64
# MIN(weather_info.Meteo_Exterior_Sol_Sud)            828 non-null float64
# MIN(weather_info.Meteo_Exterior_Piranometro)        828 non-null float64
# MIN(weather_info.Exterior_Entalpic_)                828 non-null int64
# MIN(weather_info.Exterior_Entalpic_.1)              828 non-null int64
# MIN(weather_info.Exterior_Entalpic_turbo)           828 non-null int64
# MIN(weather_info.Temperature_Exterior_Sensor)       828 non-null float64
# MIN(weather_info.Humedad_Exterior_Sensor)           828 non-null float64
# MIN(weather_info.Day_Of_Week)                       828 non-null float64
# MAX(weather_info.Temperature_Comedor_Sensor)        828 non-null float64
# MAX(weather_info.Temperature_Habitacion_Sensor)     828 non-null float64
# MAX(weather_info.Weather_Temperature)               828 non-null float64
# MAX(weather_info.CO_Comedor_Sensor)                 828 non-null float64
# MAX(weather_info.CO_Habitacion_Sensor)              828 non-null float64
# MAX(weather_info.Humedad_Comedor_Sensor)            828 non-null float64
# MAX(weather_info.Humedad_Habitacion_Sensor)         828 non-null float64
# MAX(weather_info.Lighting_Comedor_Sensor)           828 non-null float64
# MAX(weather_info.Lighting_Habitacion_Sensor)        828 non-null float64
# MAX(weather_info.Meteo_Exterior_Crepusculo)         828 non-null float64
# MAX(weather_info.Meteo_Exterior_Viento)             828 non-null float64
# MAX(weather_info.Meteo_Exterior_Sol_Oest)           828 non-null float64
# MAX(weather_info.Meteo_Exterior_Sol_Est)            828 non-null float64
# MAX(weather_info.Meteo_Exterior_Sol_Sud)            828 non-null float64
# MAX(weather_info.Meteo_Exterior_Piranometro)        828 non-null float64
# MAX(weather_info.Exterior_Entalpic_)                828 non-null int64
# MAX(weather_info.Exterior_Entalpic_.1)              828 non-null int64
# MAX(weather_info.Exterior_Entalpic_turbo)           828 non-null int64
# MAX(weather_info.Temperature_Exterior_Sensor)       828 non-null float64
# MAX(weather_info.Humedad_Exterior_Sensor)           828 non-null float64
# MAX(weather_info.Day_Of_Week)                       828 non-null float64
# MEAN(weather_info.Temperature_Comedor_Sensor)       828 non-null float64
# MEAN(weather_info.Temperature_Habitacion_Sensor)    828 non-null float64
# MEAN(weather_info.Weather_Temperature)              828 non-null float64
# MEAN(weather_info.CO_Comedor_Sensor)                828 non-null float64
# MEAN(weather_info.CO_Habitacion_Sensor)             828 non-null float64
# MEAN(weather_info.Humedad_Comedor_Sensor)           828 non-null float64
# MEAN(weather_info.Humedad_Habitacion_Sensor)        828 non-null float64
# MEAN(weather_info.Lighting_Comedor_Sensor)          828 non-null float64
# MEAN(weather_info.Lighting_Habitacion_Sensor)       828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Crepusculo)        828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Viento)            828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Sol_Oest)          828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Sol_Est)           828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Sol_Sud)           828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Piranometro)       828 non-null float64
# MEAN(weather_info.Exterior_Entalpic_)               828 non-null int64
# MEAN(weather_info.Exterior_Entalpic_.1)             828 non-null int64
# MEAN(weather_info.Exterior_Entalpic_turbo)          828 non-null int64
# MEAN(weather_info.Temperature_Exterior_Sensor)      828 non-null float64
# MEAN(weather_info.Humedad_Exterior_Sensor)          828 non-null float64
# MEAN(weather_info.Day_Of_Week)                      828 non-null float64
# dtypes: float64(72), int64(14), object(1)
# memory usage: 562.9+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sns.set_style('whitegrid')
sns.countplot(x='rain',data=data,palette='RdBu_r')

# %%
for i in range(0, 828):
    data.loc[i,('period')] = int(data['period'][i].split(":")[0])*60 + (int(data['period'][i].split(":")[1]))

# %%
data['period'] = pd.to_numeric(data['period'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828 entries, 0 to 827
# Data columns (total 87 columns):
# id                                                  828 non-null int64
# rain                                                828 non-null int64
# period                                              828 non-null int64
# SUM(weather_info.Temperature_Comedor_Sensor)        828 non-null float64
# SUM(weather_info.Temperature_Habitacion_Sensor)     828 non-null float64
# SUM(weather_info.Weather_Temperature)               828 non-null float64
# SUM(weather_info.CO_Comedor_Sensor)                 828 non-null float64
# SUM(weather_info.CO_Habitacion_Sensor)              828 non-null float64
# SUM(weather_info.Humedad_Comedor_Sensor)            828 non-null float64
# SUM(weather_info.Humedad_Habitacion_Sensor)         828 non-null float64
# SUM(weather_info.Lighting_Comedor_Sensor)           828 non-null float64
# SUM(weather_info.Lighting_Habitacion_Sensor)        828 non-null float64
# SUM(weather_info.Meteo_Exterior_Crepusculo)         828 non-null float64
# SUM(weather_info.Meteo_Exterior_Viento)             828 non-null float64
# SUM(weather_info.Meteo_Exterior_Sol_Oest)           828 non-null float64
# SUM(weather_info.Meteo_Exterior_Sol_Est)            828 non-null float64
# SUM(weather_info.Meteo_Exterior_Sol_Sud)            828 non-null float64
# SUM(weather_info.Meteo_Exterior_Piranometro)        828 non-null float64
# SUM(weather_info.Exterior_Entalpic_)                828 non-null int64
# SUM(weather_info.Exterior_Entalpic_.1)              828 non-null int64
# SUM(weather_info.Exterior_Entalpic_turbo)           828 non-null int64
# SUM(weather_info.Temperature_Exterior_Sensor)       828 non-null float64
# SUM(weather_info.Humedad_Exterior_Sensor)           828 non-null float64
# SUM(weather_info.Day_Of_Week)                       828 non-null float64
# MIN(weather_info.Temperature_Comedor_Sensor)        828 non-null float64
# MIN(weather_info.Temperature_Habitacion_Sensor)     828 non-null float64
# MIN(weather_info.Weather_Temperature)               828 non-null float64
# MIN(weather_info.CO_Comedor_Sensor)                 828 non-null float64
# MIN(weather_info.CO_Habitacion_Sensor)              828 non-null float64
# MIN(weather_info.Humedad_Comedor_Sensor)            828 non-null float64
# MIN(weather_info.Humedad_Habitacion_Sensor)         828 non-null float64
# MIN(weather_info.Lighting_Comedor_Sensor)           828 non-null float64
# MIN(weather_info.Lighting_Habitacion_Sensor)        828 non-null float64
# MIN(weather_info.Meteo_Exterior_Crepusculo)         828 non-null float64
# MIN(weather_info.Meteo_Exterior_Viento)             828 non-null float64
# MIN(weather_info.Meteo_Exterior_Sol_Oest)           828 non-null float64
# MIN(weather_info.Meteo_Exterior_Sol_Est)            828 non-null float64
# MIN(weather_info.Meteo_Exterior_Sol_Sud)            828 non-null float64
# MIN(weather_info.Meteo_Exterior_Piranometro)        828 non-null float64
# MIN(weather_info.Exterior_Entalpic_)                828 non-null int64
# MIN(weather_info.Exterior_Entalpic_.1)              828 non-null int64
# MIN(weather_info.Exterior_Entalpic_turbo)           828 non-null int64
# MIN(weather_info.Temperature_Exterior_Sensor)       828 non-null float64
# MIN(weather_info.Humedad_Exterior_Sensor)           828 non-null float64
# MIN(weather_info.Day_Of_Week)                       828 non-null float64
# MAX(weather_info.Temperature_Comedor_Sensor)        828 non-null float64
# MAX(weather_info.Temperature_Habitacion_Sensor)     828 non-null float64
# MAX(weather_info.Weather_Temperature)               828 non-null float64
# MAX(weather_info.CO_Comedor_Sensor)                 828 non-null float64
# MAX(weather_info.CO_Habitacion_Sensor)              828 non-null float64
# MAX(weather_info.Humedad_Comedor_Sensor)            828 non-null float64
# MAX(weather_info.Humedad_Habitacion_Sensor)         828 non-null float64
# MAX(weather_info.Lighting_Comedor_Sensor)           828 non-null float64
# MAX(weather_info.Lighting_Habitacion_Sensor)        828 non-null float64
# MAX(weather_info.Meteo_Exterior_Crepusculo)         828 non-null float64
# MAX(weather_info.Meteo_Exterior_Viento)             828 non-null float64
# MAX(weather_info.Meteo_Exterior_Sol_Oest)           828 non-null float64
# MAX(weather_info.Meteo_Exterior_Sol_Est)            828 non-null float64
# MAX(weather_info.Meteo_Exterior_Sol_Sud)            828 non-null float64
# MAX(weather_info.Meteo_Exterior_Piranometro)        828 non-null float64
# MAX(weather_info.Exterior_Entalpic_)                828 non-null int64
# MAX(weather_info.Exterior_Entalpic_.1)              828 non-null int64
# MAX(weather_info.Exterior_Entalpic_turbo)           828 non-null int64
# MAX(weather_info.Temperature_Exterior_Sensor)       828 non-null float64
# MAX(weather_info.Humedad_Exterior_Sensor)           828 non-null float64
# MAX(weather_info.Day_Of_Week)                       828 non-null float64
# MEAN(weather_info.Temperature_Comedor_Sensor)       828 non-null float64
# MEAN(weather_info.Temperature_Habitacion_Sensor)    828 non-null float64
# MEAN(weather_info.Weather_Temperature)              828 non-null float64
# MEAN(weather_info.CO_Comedor_Sensor)                828 non-null float64
# MEAN(weather_info.CO_Habitacion_Sensor)             828 non-null float64
# MEAN(weather_info.Humedad_Comedor_Sensor)           828 non-null float64
# MEAN(weather_info.Humedad_Habitacion_Sensor)        828 non-null float64
# MEAN(weather_info.Lighting_Comedor_Sensor)          828 non-null float64
# MEAN(weather_info.Lighting_Habitacion_Sensor)       828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Crepusculo)        828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Viento)            828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Sol_Oest)          828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Sol_Est)           828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Sol_Sud)           828 non-null float64
# MEAN(weather_info.Meteo_Exterior_Piranometro)       828 non-null float64
# MEAN(weather_info.Exterior_Entalpic_)               828 non-null int64
# MEAN(weather_info.Exterior_Entalpic_.1)             828 non-null int64
# MEAN(weather_info.Exterior_Entalpic_turbo)          828 non-null int64
# MEAN(weather_info.Temperature_Exterior_Sensor)      828 non-null float64
# MEAN(weather_info.Humedad_Exterior_Sensor)          828 non-null float64
# MEAN(weather_info.Day_Of_Week)                      828 non-null float64
# dtypes: float64(72), int64(15)
# memory usage: 562.9 KB
